# %% [markdown]
# Question 1 : Create a minimal router with two pages: Home (/) and About (/about).
# Show the links to move between pages.

# %%
import React from "react";
import { BrowserRouter as Router, Routes, Route, Link } from "react-router-dom";

function Home() {
  return <h2>Home Page</h2>;
}

function About() {
  return <h2>About Page</h2>;
}

function App() {
  return (
    <Router>
      <div>
        {/* Navigation Links */}
        <nav>
          <ul>
            <li>
              <Link to="/">Home</Link>
            </li>
            <li>
              <Link to="/about">About</Link>
            </li>
          </ul>
        </nav>

        {/* Routes */}
        <Routes>
          <Route path="/" element={<Home />} />
          <Route path="/about" element={<About />} />
        </Routes>
      </div>
    </Router>
  );
}

export default App;

# %% [markdown]
# Key Points :

# %% [markdown]
# BrowserRouter wraps the app to enable routing.
#
# Link provides navigation without reloading the page.
#
# Routes and Route define which component renders for each path.

# %% [markdown]
# Question 2 : After a user clicks “Save”, programmatically go to /thank-you.

# %% [markdown]
# To programmatically navigate to /thank-you after a user clicks Save, you can use the useNavigate hook from React Router v6.

# %%
import React from "react";
import { BrowserRouter as Router, Routes, Route, Link, useNavigate } from "react-router-dom";

function Home() {
  const navigate = useNavigate();

  const handleSave = () => {
    // Perform save logic here (e.g., API call)
    console.log("Data saved!");
    // Navigate to /thank-you
    navigate("/thank-you");
  };

  return (
    <div>
      <h2>Home Page</h2>
      <button onClick={handleSave}>Save</button>
    </div>
  );
}

function About() {
  return <h2>About Page</h2>;
}

function ThankYou() {
  return <h2>Thank You Page</h2>;
}

function App() {
  return (
    <Router>
      <nav>
        <ul>
          <li><Link to="/">Home</Link></li>
          <li><Link to="/about">About</Link></li>
        </ul>
      </nav>

      <Routes>
        <Route path="/" element={<Home />} />
        <Route path="/about" element={<About />} />
        <Route path="/thank-you" element={<ThankYou />} />
      </Routes>
    </Router>
  );
}

export default App;

# %% [markdown]
# Key Points :

# %% [markdown]
# useNavigate is the hook that lets you programmatically change routes.
#
# After the save logic runs, calling navigate("/thank-you") redirects the user.
#
# You can add any custom logic before navigation (like form validation or API calls.

# %% [markdown]
# Question 3 : Build a DashboardLayout that shows a heading and a menu. Inside it,
# render DashboardHome at /dashboard and Settings at /dashboard/settings.

# %%
import React from "react";
import { BrowserRouter as Router, Routes, Route, Link, Outlet } from "react-router-dom";

function DashboardLayout() {
  return (
    <div>
      <h1>Dashboard</h1>
      <nav>
        <ul>
          <li><Link to="/dashboard">Home</Link></li>
          <li><Link to="/dashboard/settings">Settings</Link></li>
        </ul>
      </nav>
      {/* Nested routes will render here */}
      <Outlet />
    </div>
  );
}

function DashboardHome() {
  return <h2>Dashboard Home</h2>;
}

function Settings() {
  return <h2>Settings Page</h2>;
}

function App() {
  return (
    <Router>
      <Routes>
        <Route path="/dashboard" element={<DashboardLayout />}>
          <Route index element={<DashboardHome />} />
          <Route path="settings" element={<Settings />} />
        </Route>
      </Routes>
    </Router>
  );
}

export default App;

# %% [markdown]
# Key Points :

# %% [markdown]
# DashboardLayout acts as a wrapper with a heading and menu.
#
# Outlet is where nested routes (DashboardHome, Settings) will render.
#
# Route index defines the default child route (DashboardHome) when visiting /dashboard.
#
# Route path="settings" defines the nested route at /dashboard/settings.

# %% [markdown]
# Question 4 : Create a route /users/:userId. In the UserPage component, read the
# userId from the URL and display it.

# %%
import React from "react";
import { BrowserRouter as Router, Routes, Route, Link, useParams } from "react-router-dom";

function UserPage() {
  // useParams gives access to route parameters
  const { userId } = useParams();
  return (
    <div>
      <h2>User Page</h2>
      <p>User ID: {userId}</p>
    </div>
  );
}

function Home() {
  return (
    <div>
      <h2>Home</h2>
      <ul>
        {/* Example links to different users */}
        <li><Link to="/users/1">User 1</Link></li>
        <li><Link to="/users/42">User 42</Link></li>
        <li><Link to="/users/abc">User abc</Link></li>
      </ul>
    </div>
  );
}

function App() {
  return (
    <Router>
      <Routes>
        <Route path="/" element={<Home />} />
        <Route path="/users/:userId" element={<UserPage />} />
      </Routes>
    </Router>
  );
}

export default App;

# %% [markdown]
# Key Points :

# %% [markdown]
# useParams() is the hook that lets you read dynamic parameters from the URL.
#
# The :userId in the route definition makes userId available inside UserPage.
#
# You can create links like /users/1 or /users/abc, and the component will display the corresponding ID.

# %% [markdown]
# This is the foundation for building dynamic user pages. You can expand it to fetch user data from an API based on the userId.

# %% [markdown]
# Question 5 : Only logged-in users should see /dashboard. Others should be redirected
# to /login. Write a minimal ProtectedRoute wrapper.

# %%
import React from "react";
import { BrowserRouter as Router, Routes, Route, Navigate } from "react-router-dom";

// Minimal ProtectedRoute wrapper
function ProtectedRoute({ isLoggedIn, children }) {
  if (!isLoggedIn) {
    // Redirect to /login if not authenticated
    return <Navigate to="/login" replace />;
  }
  return children;
}

function Dashboard() {
  return <h2>Dashboard Page</h2>;
}

function Login() {
  return <h2>Login Page</h2>;
}

function App() {
  // Simulate login state (replace with real auth logic)
  const isLoggedIn = false; // change to true to access dashboard

  return (
    <Router>
      <Routes>
        <Route
          path="/dashboard"
          element={
            <ProtectedRoute isLoggedIn={isLoggedIn}>
              <Dashboard />
            </ProtectedRoute>
          }
        />
        <Route path="/login" element={<Login />} />
      </Routes>
    </Router>
  );
}

export default App;

# %% [markdown]
# Key Points :

# %% [markdown]
# ProtectedRoute checks isLoggedIn.
#
# If not logged in, it returns Navigate to="/login" /
#
# If logged in, it renders the protected children (Dashboard).
#
# Replace the isLoggedIn flag with your actual authentication logic (e.g., context, Redux, or API state).

# %% [markdown]
# Question 6 : Create a counter slice with increment and decrement. Configure the store
# and provide it to React.

# %%
// counterSlice.js
import { createSlice } from "@reduxjs/toolkit";

const counterSlice = createSlice({
  name: "counter",
  initialState: { value: 0 },
  reducers: {
    increment: (state) => {
      state.value += 1;
    },
    decrement: (state) => {
      state.value -= 1;
    },
  },
});

export const { increment, decrement } = counterSlice.actions;
export default counterSlice.reducer;

# %%
// store.js
import { configureStore } from "@reduxjs/toolkit";
import counterReducer from "./counterSlice";

const store = configureStore({
  reducer: {
    counter: counterReducer,
  },
});

export default store;

# %%
// index.js
import React from "react";
import ReactDOM from "react-dom/client";
import { Provider } from "react-redux";
import store from "./store";
import App from "./App";

const root = ReactDOM.createRoot(document.getElementById("root"));
root.render(
  <Provider store={store}>
    <App />
  </Provider>
);

# %%
// App.js
import React from "react";
import { useSelector, useDispatch } from "react-redux";
import { increment, decrement } from "./counterSlice";

function App() {
  const count = useSelector((state) => state.counter.value);
  const dispatch = useDispatch();

  return (
    <div>
      <h1>Counter: {count}</h1>
      <button onClick={() => dispatch(increment())}>Increment</button>
      <button onClick={() => dispatch(decrement())}>Decrement</button>
    </div>
  );
}

export default App;

# %% [markdown]
# Key Points :

# %% [markdown]
# createSlice defines state and reducers in one place.
#
# configureStore sets up the Redux store.
#
# Provider makes the store available to React components.
#
# useSelector reads state, and useDispatch sends actions.

# %% [markdown]
# Question 7 : Build a Counter component that shows the value and buttons to increment
# and decrement using Redux hooks.

# %%
// Counter.js
import React from "react";
import { useSelector, useDispatch } from "react-redux";
import { increment, decrement } from "./counterSlice";

function Counter() {
  // Read the counter value from Redux store
  const count = useSelector((state) => state.counter.value);
  // Get dispatch function
  const dispatch = useDispatch();

  return (
    <div>
      <h2>Counter: {count}</h2>
      <button onClick={() => dispatch(increment())}>Increment</button>
      <button onClick={() => dispatch(decrement())}>Decrement</button>
    </div>
  );
}

export default Counter;

# %% [markdown]
# Key Points :

# %% [markdown]
# useSelector reads the current counter value from the store.
#
# useDispatch lets you send actions (increment, decrement).
#
# The component is reusable and can be placed anywhere in your app.

# %%
// App.js
import React from "react";
import Counter from "./Counter";

function App() {
  return (
    <div>
      <h1>Redux Counter Example</h1>
      <Counter />
    </div>
  );
}

export default App;

# %% [markdown]
# Question 8 : Create a fetchProducts thunk that loads from /api/products. Handle
# loading and error in the slice.

# %%
// productsSlice.js
import { createSlice, createAsyncThunk } from "@reduxjs/toolkit";

// Thunk to fetch products
export const fetchProducts = createAsyncThunk(
  "products/fetchProducts",
  async (_, { rejectWithValue }) => {
    try {
      const response = await fetch("/api/products");
      if (!response.ok) {
        throw new Error("Failed to fetch products");
      }
      const data = await response.json();
      return data;
    } catch (error) {
      return rejectWithValue(error.message);
    }
  }
);

const productsSlice = createSlice({
  name: "products",
  initialState: {
    items: [],
    loading: false,
    error: null,
  },
  reducers: {},
  extraReducers: (builder) => {
    builder
      .addCase(fetchProducts.pending, (state) => {
        state.loading = true;
        state.error = null;
      })
      .addCase(fetchProducts.fulfilled, (state, action) => {
        state.loading = false;
        state.items = action.payload;
      })
      .addCase(fetchProducts.rejected, (state, action) => {
        state.loading = false;
        state.error = action.payload;
      });
  },
});

export default productsSlice.reducer;

# %%
// store.js
import { configureStore } from "@reduxjs/toolkit";
import productsReducer from "./productsSlice";

const store = configureStore({
  reducer: {
    products: productsReducer,
  },
});

export default store;

# %%
// Products.js
import React, { useEffect } from "react";
import { useSelector, useDispatch } from "react-redux";
import { fetchProducts } from "./productsSlice";

function Products() {
  const { items, loading, error } = useSelector((state) => state.products);
  const dispatch = useDispatch();

  useEffect(() => {
    dispatch(fetchProducts());
  }, [dispatch]);

  if (loading) return <p>Loading products...</p>;
  if (error) return <p>Error: {error}</p>;

  return (
    <div>
      <h2>Products</h2>
      <ul>
        {items.map((product) => (
          <li key={product.id}>{product.name}</li>
        ))}
      </ul>
    </div>
  );
}

export default Products;

# %% [markdown]
# Key Points :

# %% [markdown]
# createAsyncThunk simplifies async logic and automatically generates pending, fulfilled, and rejected action types.
#
# extraReducers handles those states to update loading, error, and items.
#
# In the component, you can show loading/error states while fetching.

# %% [markdown]
# Question 9 : Style a “Buy” button using Tailwind. Use a blue background, white text,
# and change the background shade on hover and focus.

# %%
<button class="bg-blue-500 text-white px-4 py-2 rounded
               hover:bg-blue-600 focus:bg-blue-700">
  Buy
</button>

# %% [markdown]
# Key Points :

# %% [markdown]
# bg-blue-500 → sets the base background color.
#
# text-white → ensures the text is white.
#
# hover:bg-blue-600 → darkens the background when hovered.
#
# focus:bg-blue-700 → applies an even darker shade when focused (e.g., via keyboard navigation).
#
# px-4 py-2 rounded → adds padding and rounded corners for a clean look.

# %% [markdown]
# Question 10 : Create a responsive product list: on small screens one column; on
# medium and up, three columns. Add a hover transition. Also, show how to reuse a utility
# group with @apply.

# %%
<!-- ProductList.html -->
<div class="grid grid-cols-1 md:grid-cols-3 gap-4">
  <div class="product-card">
    <h3 class="text-lg font-semibold">Product 1</h3>
    <p class="text-gray-600">Description of product 1</p>
    <button class="buy-btn">Buy</button>
  </div>

  <div class="product-card">
    <h3 class="text-lg font-semibold">Product 2</h3>
    <p class="text-gray-600">Description of product 2</p>
    <button class="buy-btn">Buy</button>
  </div>

  <div class="product-card">
    <h3 class="text-lg font-semibold">Product 3</h3>
    <p class="text-gray-600">Description of product 3</p>
    <button class="buy-btn">Buy</button>
  </div>
</div>

# %%
/* styles.css */
@tailwind base;
@tailwind components;
@tailwind utilities;

/* Reusable utility group with @apply */
.product-card {
  @apply border rounded-lg p-4 shadow-sm
         transition-transform duration-300
         hover:scale-105 hover:shadow-md;
}

.buy-btn {
  @apply bg-blue-500 text-white px-4 py-2 rounded
         hover:bg-blue-600 focus:bg-blue-700
         transition-colors duration-200;
}

# %% [markdown]
# Key Points :

# %% [markdown]
# Responsive grid: grid-cols-1 md:grid-cols-3 → one column on small screens, three on medium and larger.
#
# Hover transition: transition-transform hover:scale-105 makes cards grow slightly on hover.
#
# Reusable styles: @apply lets you group Tailwind utilities into custom classes (.product-card, .buy-btn).
